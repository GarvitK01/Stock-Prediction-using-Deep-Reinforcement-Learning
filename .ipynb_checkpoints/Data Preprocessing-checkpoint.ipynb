# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn

# %%
data = pd.read_csv("./HDB.csv")

# %%
data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2016-11-17  33.005001  33.005001  32.334999  32.424999  31.726246  2446400
# 1  2016-11-18  32.584999  32.584999  31.870001  32.285000  31.589264  2107800
# 2  2016-11-21  31.990000  32.119999  31.160000  31.250000  30.576569  3148000
# 3  2016-11-22  31.570000  31.684999  31.155001  31.325001  30.649952  1890000
# 4  2016-11-23  31.180000  31.535000  31.105000  31.430000  30.752689  1878000

# %%
data.drop("Date", inplace = True, axis = 1)

# %%
data.describe()['Open']
# Out:
# count    1258.000000
# mean       54.389348
# std        12.490894
# min        29.700001
# 25%        47.000000
# 50%        50.877500
# 75%        62.687501
# max        84.699997
# Name: Open, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
def scale_data(data):
    
    train_data = data[:int(0.8 * len(data))]
    test_data = data[int(0.8 * len(data)):]
    
    scaler = MinMaxScaler()
    
    for column in train_data.columns:
        
        values = train_data[column]
        values = np.array(values)
        values = values.reshape(-1, 1)
        train_data[column] = scaler.fit_transform(values)
        train_data[column] = train_data[column].apply(lambda X: round(X, 4))
        
        values = test_data[column]
        values = np.array(values)
        values = values.reshape(-1, 1)
        test_data[column] = scaler.fit_transform(values)
        test_data[column] = test_data[column].apply(lambda X: round(X, 4))
        
        
        
    return train_data, test_data

# %%
train_data, test_data = scale_data(data)
# Out:
# /tmp/ipykernel_44760/1572262777.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = train_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = test_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = train_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = test_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = train_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = test_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = train_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = test_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = train_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = test_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data[column] = train_data[column].apply(lambda X: round(X, 4))
# /tmp/ipykernel_44760/1572262777.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = scaler.fit_transform(values)
# /tmp/ipykernel_44760/1572262777.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data[column] = test_data[column].apply(lambda X: round(X, 4))

# %%
train_data.head()
# Out:
#     Open   High    Low  Close  Adj Close  Volume
# 0  0.084  0.078  0.073  0.072      0.070  0.2140
# 1  0.073  0.067  0.061  0.069      0.067  0.1791
# 2  0.058  0.055  0.043  0.042      0.041  0.2863
# 3  0.048  0.044  0.042  0.044      0.043  0.1566
# 4  0.038  0.041  0.041  0.047      0.046  0.1554

# %%
test_data.head()
# Out:
#        Open   High    Low  Close  Adj Close  Volume
# 1006  0.131  0.147  0.148  0.126      0.126  0.1984
# 1007  0.150  0.142  0.069  0.038      0.038  0.3754
# 1008  0.007  0.000  0.023  0.007      0.007  0.2265
# 1009  0.035  0.030  0.020  0.000      0.000  0.2283
# 1010  0.033  0.027  0.025  0.006      0.006  0.1195

# %%
preprocessed = pd.concat([train_data, test_data], axis = 0)

# %%
preprocessed.to_csv("process.csv", index=False)

# %%
df = pd.read_csv("./process.csv")

# %%
df
# Out:
#        Open   High    Low  Close  Adj Close  Volume
# 0     0.084  0.078  0.073  0.072      0.070  0.2140
# 1     0.073  0.067  0.061  0.069      0.067  0.1791
# 2     0.058  0.055  0.043  0.042      0.041  0.2863
# 3     0.048  0.044  0.042  0.044      0.043  0.1566
# 4     0.038  0.041  0.041  0.047      0.046  0.1554
# ...     ...    ...    ...    ...        ...     ...
# 1253  0.279  0.272  0.306  0.285      0.300  0.2097
# 1254  0.269  0.267  0.303  0.281      0.296  0.1106
# 1255  0.259  0.305  0.307  0.304      0.319  0.1555
# 1256  0.291  0.308  0.297  0.260      0.274  0.0767
# 1257  0.249  0.237  0.242  0.226      0.240  0.2231
#
# [1258 rows x 6 columns]

# %%
np.array(df.loc[0])
# Out:
# array([0.084, 0.078, 0.073, 0.072, 0.07 , 0.214])
